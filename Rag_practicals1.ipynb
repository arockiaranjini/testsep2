# %% [markdown]
# <a href="https://colab.research.google.com/github/arockiaranjini/testsep2/blob/main/Rag_practicals1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
#pipe = pipeline("text-generation", model="meta-llama/Llama-3.2-1B-Instruct", eos_token_id=pipe.tokenizer.eos_token_id, return_full_text=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-647751856.py in <cell line: 0>()
#       1 from transformers import pipeline
# ----> 2 pipe = pipeline("text-generation", model="meta-llama/Llama-3.2-1B-Instruct", eos_token_id=pipe.tokenizer.eos_token_id, return_full_text=False)
#
# NameError: name 'pipe' is not defined

# %%
from transformers import pipeline
# Load model directly
pipe = pipeline("text-generation", model = "gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
question1 = "What is an ACE?"
question2 = "What is a volley?"

prompt = "Answer the question\n" + \
"Question: "+ question1 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question
# Question: What is an ACE?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Answer the question\nQuestion: What is an ACE?\nAnswer: ACE is a software program designed to help students learn, develop and improve their English language skills. ACE helps students learn by creating a curriculum that is aligned with their needs.\nHere are some examples of how to teach:\nTeachers can teach the'}]

# %%
context = """ACE is a serve that lands in the correct
service court without the receiving player touching
it with their racket, resulting in a point for the server.
When a player hits an ace, they immediately win the point,
regardless of the opponent's position or attempted return.
The term ace in tennis was coined by sports journalist Allison Danzig. """

# %%
prompt = "Answer the question using the below context.\n" + \
"Context: " + context + "\n" + \
"Question: "+ question1 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question using the below context.
# Context: ACE is a serve that lands in the correct
# service court without the receiving player touching
# it with their racket, resulting in a point for the server.
# When a player hits an ace, they immediately win the point,
# regardless of the opponent's position or attempted return.
# The term ace in tennis was coined by sports journalist Allison Danzig.
# Question: What is an ACE?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Answer the question using the below context.\nContext: ACE is a serve that lands in the correct\nservice court without the receiving player touching\nit with their racket, resulting in a point for the server.\nWhen a player hits an ace, they immediately win the point,\nregardless of the opponent's position or attempted return.\nThe term ace in tennis was coined by sports journalist Allison Danzig. \nQuestion: What is an ACE?\nAnswer: ACE is a service that lands in the correct\nservice court without the receiving player touching it with their racket, resulting in a point for the server.\nWhen a player hits an ace, they immediately win the point, regardless of the opponent's position"}]

# %%
context = """In tennis, a volley is a shot where the
ball is struck before it bounces on the ground,
typically performed near the net,
aiming to end the point quickly or
disrupt the opponent's rhythm."""

# %%
prompt = "Answer the question using the below context.\n" + \
"Context: " + context + "\n" + \
"Question: "+ question2 + "\n" + "Answer:"
print(prompt)
# Out:
# Answer the question using the below context.
# Context: In tennis, a volley is a shot where the
# ball is struck before it bounces on the ground,
# typically performed near the net,
# aiming to end the point quickly or
# disrupt the opponent's rhythm.
# Question: What is a volley?
# Answer:

# %%
result = pipe(prompt, max_new_tokens = 50)
print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Answer the question using the below context.\nContext: In tennis, a volley is a shot where the\nball is struck before it bounces on the ground,\ntypically performed near the net,\naiming to end the point quickly or\ndisrupt the opponent\'s rhythm.\nQuestion: What is a volley?\nAnswer: A volley is a shot where the ball is struck\nbefore it bounces on the ground, typically performed\nnear the net,aiming to end the point quickly ordisrupt the opponent\'s rhythm.\nExample: What is the "shot" of'}]
